# %% [markdown]
# <a href="https://colab.research.google.com/github/cool1014/bigdata-engineer-study/blob/main/%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 데이터 로드
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/JEunJin/BigData_python/refs/heads/master/bigdata_csvfile/cardiovascular_heart_disease_data.csv')

from statsmodels.formula.api import logit

model = logit(
    'cardio ~ weight + cholesterol + smoke',
    data=df
)

result = model.fit()

print(result.summary())

# 오즈비 계산
import numpy as np

print(np.exp(result.params))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.654936
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:                 cardio   No. Observations:                70000
# Model:                          Logit   Df Residuals:                    69996
# Method:                           MLE   Df Model:                            3
# Date:                Fri, 19 Jun 2026   Pseudo R-squ.:                 0.05513
# Time:                        18:25:57   Log-Likelihood:                -45846.
# converged:                       True   LL-Null:                       -48520.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -2.6205      0.046    -57.563      0.000      -2.710      -2.531
# ...
